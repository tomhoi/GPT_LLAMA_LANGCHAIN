# %% [markdown]
# ### Installation

# %%
# !pip install llama_index -q
# !pip install langchain -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 KB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.3/404.3 KB 31.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 75.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 KB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 11.4 MB/s eta 0:00:00
#   Building wheel for llama_index (setup.py) ... done

# %% [markdown]
# ### Set the working directory

# %%
working_directory = 'D:\Documents_D\GitHub\GPT_LLAMA_LANGCHAIN'

# %% [markdown]
# ### Importing

# %%
# Import modules from llama_index and langchain
from llama_index import SimpleDirectoryReader, GPTSimpleVectorIndex, LLMPredictor, PromptHelper
from langchain import OpenAI
import os
from IPython.display import Markdown, display

# %% [markdown]
# ### Create index.json

# %%
def construct_index(directory_path):
    # set maximum input size
    max_input_size = 4096
    # set number of output tokens
    num_outputs = 256
    # set maximum chunk overlap
    max_chunk_overlap = 20
    # set chunk size limit
    chunk_size_limit = 600

    # define LLM (ChatGPT gpt-3.5-turbo)
    llm_predictor = LLMPredictor(llm = OpenAI(temperature=0, 
                                              model_name = "gpt-3.5-turbo", 
                                              max_tokens = num_outputs))
    
    prompt_helper = PromptHelper(max_input_size, 
                                 num_outputs, 
                                 max_chunk_overlap, 
                                 chunk_size_limit = chunk_size_limit)
 
    documents = SimpleDirectoryReader(directory_path).load_data()
    
    index = GPTSimpleVectorIndex(
        documents, llm_predictor=llm_predictor, prompt_helper=prompt_helper
        )

    index.save_to_disk(working_directory + 'index.json')

    return index

# %%
# Set OpenAI key
openai_key = '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'
os.environ["OPENAI_API_KEY"] = openai_key

# %%
construct_index(working_directory + 'data')

# %% [markdown]
# ### Chatbot 1

# %%
def ask_chatbot1():
    index = GPTSimpleVectorIndex.load_from_disk(working_directory + '\index.json')
    while True: 
        query = input("Your querry: ")
        response = index.query(query, response_mode = "compact")

        display(Markdown(f"You asked: <b>{query}</b>"))
        display(Markdown(f"Bot says: <b>{response.response}</b>"))

# %%
ask_chatbot1()
# Out:
# INFO:llama_index.token_counter.token_counter:> [query] Total LLM token usage: 429 tokens
# INFO:llama_index.token_counter.token_counter:> [query] Total embedding token usage: 4 tokens
# You asked: <b>how are you?</b>
# Bot says: <b>
# I'm doing well, thank you!</b>
# INFO:openai:error_code=None error_message="[''] is not valid under any of the given schemas - 'input'" error_param=None error_type=invalid_request_error message='OpenAI API error received' stream_error=False
# INFO:openai:error_code=None error_message="[''] is not valid under any of the given schemas - 'input'" error_param=None error_type=invalid_request_error message='OpenAI API error received' stream_error=False
# INFO:openai:error_code=None error_message="[''] is not valid under any of the given schemas - 'input'" error_param=None error_type=invalid_request_error message='OpenAI API error received' stream_error=False
# INFO:openai:error_code=None error_message="[''] is not valid under any of the given schemas - 'input'" error_param=None error_type=invalid_request_error message='OpenAI API error received' stream_error=False
# INFO:openai:error_code=None error_message="[''] is not valid under any of the given schemas - 'input'" error_param=None error_type=invalid_request_error message='OpenAI API error received' stream_error=False
# INFO:openai:error_code=None error_message="[''] is not valid under any of the given schemas - 'input'" error_param=None error_type=invalid_request_error message='OpenAI API error received' stream_error=False
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# c:\Users\hanhb\anaconda3\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     381                 try:
# --> 382                     result = fn(*args, **kwargs)
#     383                 except BaseException:  # noqa: B902
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\embeddings\openai.py in get_embedding(text, engine)
#     105     text = text.replace("\n", " ")
# --> 106     return openai.Embedding.create(input=[text], engine=engine)["data"][0]["embedding"]
#     107
#
# c:\Users\hanhb\anaconda3\lib\site-packages\openai\api_resources\embedding.py in create(cls, *args, **kwargs)
#      32             try:
# ---> 33                 response = super().create(*args, **kwargs)
#      34
#
# c:\Users\hanhb\anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#
# c:\Users\hanhb\anaconda3\lib\site-packages\openai\api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     225         )
# --> 226         resp, got_stream = self._interpret_response(result, stream)
#     227         return resp, got_stream, self.api_key
#
# c:\Users\hanhb\anaconda3\lib\site-packages\openai\api_requestor.py in _interpret_response(self, result, stream)
#     618             return (
# --> 619                 self._interpret_response_line(
#     620                     result.content.decode("utf-8"),
#
# c:\Users\hanhb\anaconda3\lib\site-packages\openai\api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     681         if stream_error or not 200 <= rcode < 300:
# --> 682             raise self.handle_error_response(
#     683                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#
# InvalidRequestError: [''] is not valid under any of the given schemas - 'input'
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14140\1324896896.py in <module>
# ----> 1 ask_chatbot1()
#
# ~\AppData\Local\Temp\ipykernel_14140\2824408429.py in ask_chatbot1()
#       3     while True:
#       4         query = input("Your querry: ")
# ----> 5         response = index.query(query, response_mode = "compact")
#       6
#       7         display(Markdown(f"You asked: <b>{query}</b>"))
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\indices\base.py in query(self, query_str, mode, query_transform, use_async, **query_kwargs)
#     422                 use_async=use_async,
#     423             )
# --> 424             return query_runner.query(query_str, self._index_struct)
#     425
#     426     async def aquery(
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\indices\query\query_runner.py in query(self, query_str_or_bundle, index_struct)
#     181             query_bundle = query_str_or_bundle
#     182
# --> 183         return query_combiner.run(query_obj, query_bundle)
#     184         # return query_obj.query(query_bundle)
#     185
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\indices\query\query_combiner\base.py in run(self, query_obj, query_bundle)
#      52             query_bundle, extra_info=transform_extra_info
#      53         )
# ---> 54         return query_obj.query(updated_query_bundle)
#      55
#      56
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\token_counter\token_counter.py in wrapped_llm_predict(_self, *args, **kwargs)
#      84         def wrapped_llm_predict(_self: Any, *args: Any, **kwargs: Any) -> Any:
#      85             with wrapper_logic(_self):
# ---> 86                 f_return_val = f(_self, *args, **kwargs)
#      87
#      88             return f_return_val
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\indices\query\base.py in query(self, query_bundle)
#     400     def query(self, query_bundle: QueryBundle) -> RESPONSE_TYPE:
#     401         """Answer a query."""
# --> 402         response = self._query(query_bundle)
#     403         # if include_summary is True, then include summary text in answer
#     404         # summary text is set through `set_text` on the underlying index.
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\indices\query\base.py in _query(self, query_bundle)
#     370         """Answer a query."""
#     371         # TODO: remove _query and just use query
# --> 372         tuples = self.get_nodes_and_similarities_for_response(query_bundle)
#     373
#     374         # prepare response builder
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\indices\query\base.py in get_nodes_and_similarities_for_response(self, query_bundle)
#     294         """
#     295         similarity_tracker = SimilarityTracker()
# --> 296         nodes = self._get_nodes_for_response(
#     297             query_bundle, similarity_tracker=similarity_tracker
#     298         )
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\indices\query\vector_store\base.py in _get_nodes_for_response(self, query_bundle, similarity_tracker)
#      44     ) -> List[Node]:
#      45         if query_bundle.embedding is None:
# ---> 46             query_bundle.embedding = self._embed_model.get_agg_embedding_from_queries(
#      47                 query_bundle.embedding_strs
#      48             )
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\embeddings\base.py in get_agg_embedding_from_queries(self, queries, agg_fn)
#      77     ) -> List[float]:
#      78         """Get aggregated embedding from multiple queries."""
# ---> 79         query_embeddings = [self.get_query_embedding(query) for query in queries]
#      80         agg_fn = agg_fn or mean_agg
#      81         return agg_fn(query_embeddings)
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\embeddings\base.py in <listcomp>(.0)
#      77     ) -> List[float]:
#      78         """Get aggregated embedding from multiple queries."""
# ---> 79         query_embeddings = [self.get_query_embedding(query) for query in queries]
#      80         agg_fn = agg_fn or mean_agg
#      81         return agg_fn(query_embeddings)
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\embeddings\base.py in get_query_embedding(self, query)
#      66     def get_query_embedding(self, query: str) -> List[float]:
#      67         """Get query embedding."""
# ---> 68         query_embedding = self._get_query_embedding(query)
#      69         query_tokens_count = len(self._tokenizer(query))
#      70         self._total_tokens_used += query_tokens_count
#
# c:\Users\hanhb\anaconda3\lib\site-packages\llama_index\embeddings\openai.py in _get_query_embedding(self, query)
#     220                 raise ValueError(f"Invalid mode, model combination: {key}")
#     221             engine = _QUERY_MODE_MODEL_DICT[key]
# --> 222         return get_embedding(query, engine=engine)
#     223
#     224     def _get_text_embedding(self, text: str) -> List[float]:
#
# c:\Users\hanhb\anaconda3\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
#     288         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289             return self(f, *args, **kw)
#     290
#     291         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# c:\Users\hanhb\anaconda3\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     377         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378         while True:
# --> 379             do = self.iter(retry_state=retry_state)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
#
# c:\Users\hanhb\anaconda3\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     324             if self.reraise:
#     325                 raise retry_exc.reraise()
# --> 326             raise retry_exc from fut.exception()
#     327
#     328         if self.wait:
#
# RetryError: RetryError[<Future at 0x2b84b868f10 state=finished raised InvalidRequestError>]

# %% [markdown]
# ### Chatbot 2

# %%
def ask_chatbot2(question):

    index = GPTSimpleVectorIndex.load_from_disk(working_directory + '\index.json')
    response = index.query(question, response_mode = "compact")

    display(Markdown(f"You asked: <b>{question}</b>"))
    display(Markdown(f"Bot says: <b>{response.response}</b>"))

# %%
question = "Why people cook at home?"
ask_chatbot2(question)
# Out:
# INFO:llama_index.token_counter.token_counter:> [query] Total LLM token usage: 614 tokens
# INFO:llama_index.token_counter.token_counter:> [query] Total embedding token usage: 6 tokens
# You asked: <b>Why people cook at home?</b>
# Bot says: <b>
# People cook at home for a variety of reasons, including to relax and unwind after a long day, to save money, to have control over what goes into their meals, to spend time with family, and to experiment with different recipes and ingredients.</b>
